# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np

# %%
response = requests.get("https://www1.nyc.gov/site/tlc/about/tlc-trip-record-data.page").text

# %%
response = requests.get("https://www1.nyc.gov/site/tlc/about/tlc-trip-record-data.page").text
soup = BeautifulSoup(response, "html.parser")

# %%
#soup.find_all("div", {"class": "faq-answers"})
list_of_years = soup.select(".faq-questions")#[0].find_all("ul")
years_available = [year.get_text(strip=True) for year in list_of_years]
years_available
# Out:
# ['2020',
#  '2019',
#  '2018',
#  '2017',
#  '2016',
#  '2015',
#  '2014',
#  '2013',
#  '2012',
#  '2011',
#  '2010',
#  '2009']

# %%
pdDF = pd.DataFrame(columns=['year', 'month', 'link', 'description'])
pdDF
# Out:
# Empty DataFrame
# Columns: [year, month, link, description]
# Index: []

# %%
df = pd.DataFrame()
years = soup.select(".faq-answers")
#months[0].select('li')[0].a['href']
#years[2].find_all(['p', 'b'])#[0].p.text
years
# Out:
# [<div class="faq-answers" id="faq2020">
#  <p>Due to COVID-19 and its impact on the daily operations of small businesses, TLC granted smaller bases an extension on trip record submissions. Trip and trip-related data for these bases will be updated as it becomes available.</p>
#  <table border="1" cellpadding="5" style="border-color: #666666; border-width: 1px; height: auto;" width="100%">
#  <tbody>
#  <tr valign="top">
#  <td><b>
#  <p>January</p>
#  </b>
#  <ul>
#  <li><a href="https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2020-01.csv">Yellow Taxi Trip Records</a> (CSV)</li>
#  <li><a href="https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2020-01.csv">Green Taxi Trip Records</a> (CSV)</li>
#  <li><a href="https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2020-01.csv">For-Hire Vehicle Trip Records</a> (CSV)</li>
#  <li><a href="https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2020-01.csv">High Volume For-Hire Vehicle Trip Records</a> (CSV)</li>
# ...

# %%
table = [elem.select('td') for elem in years]
tab = []
for elem in table:
    tab.extend(elem)
#table[0].find_all(['p', 'ul'])
#table[0].b.next_sibling.next_sibling
tab
# Out:
# [<td><b>
#  <p>January</p>
#  </b>
#  <ul>
#  <li><a href="https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2020-01.csv">Yellow Taxi Trip Records</a> (CSV)</li>
#  <li><a href="https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2020-01.csv">Green Taxi Trip Records</a> (CSV)</li>
#  <li><a href="https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2020-01.csv">For-Hire Vehicle Trip Records</a> (CSV)</li>
#  <li><a href="https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2020-01.csv">High Volume For-Hire Vehicle Trip Records</a> (CSV)</li>
#  </ul>
#  <p><b>February</b></p>
#  <ul>
#  <li><a href="https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2020-02.csv">Yellow Taxi Trip Records</a> (CSV)</li>
#  <li><a href="https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2020-02.csv">Green Taxi Trip Records</a> (CSV)</li>
#  <li><a href="https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2020-02.csv">For-Hire Vehicle Trip Records</a> (CSV)</li>
# ...

# %%
taxis = [ul.select('ul') for ul in years]
taxis
# Out:
# [[<ul>
#   <li><a href="https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2020-01.csv">Yellow Taxi Trip Records</a> (CSV)</li>
#   <li><a href="https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2020-01.csv">Green Taxi Trip Records</a> (CSV)</li>
#   <li><a href="https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2020-01.csv">For-Hire Vehicle Trip Records</a> (CSV)</li>
#   <li><a href="https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2020-01.csv">High Volume For-Hire Vehicle Trip Records</a> (CSV)</li>
#   </ul>,
#   <ul>
#   <li><a href="https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2020-02.csv">Yellow Taxi Trip Records</a> (CSV)</li>
#   <li><a href="https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2020-02.csv">Green Taxi Trip Records</a> (CSV)</li>
#   <li><a href="https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2020-02.csv">For-Hire Vehicle Trip Records</a> (CSV)</li>
# ...

# %% [markdown]
# links = [li.select('li') for elem in taxis for li in elem]
# links

# %%
tab[1]
# Out:
# <td>
# <p><b>July</b></p>
# <ul>
# <li><a href="https://nyc-tlc.s3.amazonaws.com/trip+data/yellow_tripdata_2020-07.csv">Yellow Taxi Trip Records</a> (CSV)</li>
# <li><a href="https://nyc-tlc.s3.amazonaws.com/trip+data/green_tripdata_2020-07.csv">Green Taxi Trip Records</a> (CSV)</li>
# <li><a href="https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2020-07.csv">FHV Trip Records</a> (CSV)</li>
# <li><a href="https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2020-07.csv">High Volume For-Hire Vehicle Trip Records</a> (CSV)</li>
# </ul>
# <p><b>August</b></p>
# <ul>
# <li><a href="https://nyc-tlc.s3.amazonaws.com/trip+data/yellow_tripdata_2020-08.csv">Yellow Taxi Trip Records</a> (CSV)</li>
# <li><a href="https://nyc-tlc.s3.amazonaws.com/trip+data/green_tripdata_2020-08.csv">Green Taxi Trip Records</a> (CSV)</li>
# <li><a href="https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2020-08.csv">FHV Trip Records</a> (CSV)</li>
# ...

# %%
tab[0].find('p', string="June").next_sibling.next_sibling
# Out:
# <ul>
# <li><a href="https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2020-06.csv">Yellow Taxi Trip Records</a> (CSV)</li>
# <li><a href="https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2020-06.csv">Green Taxi Trip Records</a> (CSV)</li>
# <li><a href="https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2020-06.csv">For-Hire Vehicle Trip Records</a> (CSV)</li>
# <li><a href="https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2020-06.csv">High Volume For-Hire Vehicle Trip Records</a> (CSV)</li>
# </ul>

# %%
h = []
for elem in tab[:2]:
    m = elem.find_all('b')
    h.append([a.get_text(strip=True) for a in m])
print(h)
# Out:
# [['January', 'February', 'March', 'April', 'May', 'June'], ['July', 'August', 'September', 'October', 'November', 'December']]

# %%
for href in tab:
    g = href.find_all('ul')
    print(g)
# Out:
# [<ul>
# <li><a href="https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2020-01.csv">Yellow Taxi Trip Records</a> (CSV)</li>
# <li><a href="https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2020-01.csv">Green Taxi Trip Records</a> (CSV)</li>
# <li><a href="https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2020-01.csv">For-Hire Vehicle Trip Records</a> (CSV)</li>
# <li><a href="https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2020-01.csv">High Volume For-Hire Vehicle Trip Records</a> (CSV)</li>
# </ul>, <ul>
# <li><a href="https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2020-02.csv">Yellow Taxi Trip Records</a> (CSV)</li>
# <li><a href="https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2020-02.csv">Green Taxi Trip Records</a> (CSV)</li>
# <li><a href="https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2020-02.csv">For-Hire Vehicle Trip Records</a> (CSV)</li>
# ...

# %%
for elem in tab[:2]:
    m = elem.find_all('b')
    h = [a.get_text(strip=True) for a in m]
    print(h)
# Out:
# ['January', 'February', 'March', 'April', 'May', 'June']
# ['July', 'August', 'September', 'October', 'November', 'December']

# %%
tab[2].find_all('b')
# Out:
# [<b>
#  <p>January</p>
#  </b>,
#  <b>February</b>,
#  <b>March</b>,
#  <b>April</b>,
#  <b>May</b>,
#  <b>June</b>]

# %%
def soup(year):
    
    response = requests.get("https://www1.nyc.gov/site/tlc/about/tlc-trip-record-data.page").text
    soup = BeautifulSoup(response, "html.parser")
    #attrs={"class":"about-book","id":"aboutbook"}
    years = soup.find_all("div", id=f"faq{year}")[0]
    
    return years

# %%
year = soup(2019)
year
# Out:
# <div class="faq-answers" id="faq2019">
# <table border="1" cellpadding="5" style="border-color: #666666; border-width: 1px; height: auto;" width="100%">
# <tbody>
# <tr valign="top">
# <td><b>
# <p>January</p>
# </b>
# <ul>
# <li><a href="https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2019-01.csv">Yellow Taxi Trip Records</a> (CSV)</li>
# <li><a href="https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2019-01.csv">Green Taxi Trip Records</a> (CSV)</li>
# <li><a href="https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2019-01.csv">For-Hire Vehicle Trip Records</a> (CSV)</li>
# </ul>
# <p><b>February</b></p>
# <ul>
# <li><a href="https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2019-02.csv">Yellow Taxi Trip Records</a> (CSV)</li>
# <li><a href="https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2019-02.csv">Green Taxi Trip Records</a> (CSV)</li>
# ...

# %%
year.find_all('li')[0].a['href']
# Out:
# 'https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2019-01.csv'

# %%
filter_by_month = year.find(string=f"January").parent.findNext('ul')
print(filter_by_month)
gh = pd.DataFrame({'links':[elem.a['href'] for elem in filter_by_month.find_all('li')]})
pd.set_option('display.max_colwidth', None)
gh
# Out:
# <ul>
# <li><a href="https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2019-01.csv">Yellow Taxi Trip Records</a> (CSV)</li>
# <li><a href="https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2019-01.csv">Green Taxi Trip Records</a> (CSV)</li>
# <li><a href="https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2019-01.csv">For-Hire Vehicle Trip Records</a> (CSV)</li>
# </ul>
#                                                                     links
# 0  https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2019-01.csv
# 1   https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2019-01.csv
# 2     https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2019-01.csv

# %%
months_available = [elem.get_text(strip=True) for elem in year.find_all(['b'])]

# %%
months = [elem.get_text(strip=True) for elem in year.find_all(['b'])]

# %%
months
# Out:
# ['January',
#  'February',
#  'March',
#  'April',
#  'May',
#  'June',
#  'July',
#  'August',
#  'September',
#  'October',
#  'November',
#  'December']

# %%
def df(year, month):
    year_html = soup(year)
    months_available = [elem.get_text(strip=True) for elem in year_html.find_all(['b'])]
    
    if month not in months_available:
        raise ValueError(f"month provided does not match with available months, check spelling {months_available}")
        
    filter_by_month = year_html.find(string=f"{month}").parent.findNext('ul')
    links = [elem.a['href'] for elem in filter_by_month.find_all('li')]
    description = [elem.a.text for elem in filter_by_month.find_all('li')]
    
    final_df = pd.DataFrame({'month': month, 'links': links, 'description': description})
    pd.set_option('display.max_colwidth', None)
    
    return final_df

# %%
def final_df(year, *month):
    
    final_df = pd.DataFrame()
    
    for elem in month:
        final_df = final_df.append(df(year, elem), ignore_index=True)
        
    return final_df

result = final_df(2020, 'January', 'February', 'March')
result
# Out:
#        month  \
# 0    January
# 1    January
# 2    January
# 3    January
# 4   February
# 5   February
# 6   February
# 7   February
# 8      March
# 9      March
# 10     March
# 11     March
#
#                                                                      links  \
# 0   https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2020-01.csv
# 1    https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2020-01.csv
# 2      https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2020-01.csv
# 3    https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2020-01.csv
# 4   https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2020-02.csv
# 5    https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2020-02.csv
# 6      https://nyc-tlc.s3.amazonaws.com/trip+data/fhv_tripdata_2020-02.csv
# 7    https://nyc-tlc.s3.amazonaws.com/trip+data/fhvhv_tripdata_2020-02.csv
# 8   https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2020-03.csv
# ...

# %%
csv = result[result['description'].str.contains('Yellow')]['links'][0]
csv
# Out:
# 'https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2020-01.csv'

# %%
prueba = pd.read_csv(csv)
# Out:
# /home/david/miniconda3/envs/work/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3147: DtypeWarning: Columns (6) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
prueba
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0             1.0  2020-01-01 00:28:15   2020-01-01 00:33:03              1.0
# 1             1.0  2020-01-01 00:35:39   2020-01-01 00:43:04              1.0
# 2             1.0  2020-01-01 00:47:41   2020-01-01 00:53:52              1.0
# 3             1.0  2020-01-01 00:55:23   2020-01-01 01:00:14              1.0
# 4             2.0  2020-01-01 00:01:58   2020-01-01 00:04:16              1.0
# ...           ...                  ...                   ...              ...
# 6405003       NaN  2020-01-31 22:51:00   2020-01-31 23:22:00              NaN
# 6405004       NaN  2020-01-31 22:10:00   2020-01-31 23:26:00              NaN
# 6405005       NaN  2020-01-31 22:50:07   2020-01-31 23:17:57              NaN
# 6405006       NaN  2020-01-31 22:25:53   2020-01-31 22:48:32              NaN
# 6405007       NaN  2020-01-31 22:44:00   2020-01-31 23:06:00              NaN
#
# ...

# %%
prueba.dtypes
# Out:
# VendorID                 float64
# tpep_pickup_datetime      object
# tpep_dropoff_datetime     object
# passenger_count          float64
# trip_distance            float64
# RatecodeID               float64
# store_and_fwd_flag        object
# PULocationID               int64
# DOLocationID               int64
# payment_type             float64
# fare_amount              float64
# extra                    float64
# mta_tax                  float64
# tip_amount               float64
# tolls_amount             float64
# improvement_surcharge    float64
# total_amount             float64
# congestion_surcharge     float64
# dtype: object

# %%
type_object = prueba.select_dtypes(include='object').columns.to_list()
type_object.pop()#.astype('str').dtypes

prueba[type_object].head()
# Out:
#   tpep_pickup_datetime tpep_dropoff_datetime
# 0  2020-01-01 00:28:15   2020-01-01 00:33:03
# 1  2020-01-01 00:35:39   2020-01-01 00:43:04
# 2  2020-01-01 00:47:41   2020-01-01 00:53:52
# 3  2020-01-01 00:55:23   2020-01-01 01:00:14
# 4  2020-01-01 00:01:58   2020-01-01 00:04:16

# %%
for elem in type_object:
    prueba[f"{elem}"] = pd.to_datetime(prueba[f"{elem}"], yearfirst=True, format="%Y/%m/%d")
prueba.dtypes
# Out:
# VendorID                        float64
# tpep_pickup_datetime     datetime64[ns]
# tpep_dropoff_datetime    datetime64[ns]
# passenger_count                 float64
# trip_distance                   float64
# RatecodeID                      float64
# store_and_fwd_flag               object
# PULocationID                      int64
# DOLocationID                      int64
# payment_type                    float64
# fare_amount                     float64
# extra                           float64
# mta_tax                         float64
# tip_amount                      float64
# tolls_amount                    float64
# improvement_surcharge           float64
# total_amount                    float64
# congestion_surcharge            float64
# dtype: object

# %%
aasdasprueba['tpep_dropoff_datetime'] = pd.to_datetime(prueba['tpep_dropoff_datetime'], yearfirst=True, format="%Y/%m/%d")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-23091599c6f3> in <module>
# ----> 1 aasdasprueba['tpep_dropoff_datetime'] = pd.to_datetime(prueba['tpep_dropoff_datetime'], yearfirst=True, format="%Y/%m/%d")
#
# NameError: name 'aasdasprueba' is not defined

# %%
#tuples = [tuple(x) for x in prueba.to_numpy()]
#tuples

# %%
cols = ','.join(list(prueba.columns))
cols
# Out:
# 'VendorID,tpep_pickup_datetime,tpep_dropoff_datetime,passenger_count,trip_distance,RatecodeID,store_and_fwd_flag,PULocationID,DOLocationID,payment_type,fare_amount,extra,mta_tax,tip_amount,tolls_amount,improvement_surcharge,total_amount,congestion_surcharge'

# %%
import psycopg2

param_dic = {
    "host"      : "127.0.0.1",
    "database"  : "taxis",
    "user"      : "postgres",
    "password"  : "Snowdav3"
}

def connect(params_dic):
    """ Connect to the PostgreSQL database server """
    conn = None
    try:
        # connect to the PostgreSQL server
        print('Connecting to the PostgreSQL database...')
        conn = psycopg2.connect(**params_dic)
    except (Exception, psycopg2.DatabaseError) as error:
        print(error)
        sys.exit(1) 
    print("Connection successful")
    return conn
conn = connect(param_dic)

# %%
sdfgsafdf

# %% [markdown]
#    FIRST_NAME CHAR(20) NOT NULL,
#    LAST_NAME CHAR(20),
#    AGE INT,
#    SEX CHAR(1),
#    INCOME FLOAT

# %%
cursor = conn.cursor()

sql ='''CREATE TABLE yellowtaxis(
   VendorID float,
   tpep_pickup_datetime timestamp,
   tpep_dropoff_datetime timestamp,
   passenger_count float,
   trip_distance float,
   RatecodeID float,
   store_and_fwd_flag varchar,
   PULocationID float,
   DOLocationID float,
   payment_type float,
   fare_amount float,
   extra float,
   mta_tax float,
   tip_amount float,
   tolls_amount float,
   improvement_surcharge float,
   total_amount float,
   congestion_surcharge float
);'''

# %% [markdown]
# sql ='''CREATE TABLE prueba1(
#    FIRST_NAME char(20),
#    LAST_NAME char(20),
#    AGE int,
#    SEX char(1),
#    INCOME float
# );'''
# cursor.execute(sql)
# conn.commit()

# %%
cursor.execute(sql)
conn.commit()

# %%
conn

# %%
prueba

# %%
conn.rollback()

# %%
import psycopg2.extras as extras

def execute_batch(conn, df, table, page_size=100):
    """
    Using psycopg2.extras.execute_batch() to insert the dataframe
    """
    print("Converting DataFrame rows into tuples")
    tuples = [tuple(x) for x in df.to_numpy()]
    # Comma-separated dataframe columns
    cols = ','.join(list(df.columns))
    # SQL quert to execute
    query  = "INSERT INTO %s(%s) VALUES(%%s,%%s,%%s,%%s,%%s,%%s,%%s,%%s,%%s,%%s,%%s,%%s,%%s,%%s,%%s,%%s,%%s,%%s)" % (table, cols)
    cursor = conn.cursor()
    try:
        print(f"Inserting values into the {table} table")
        extras.execute_batch(cursor, query, tuples, page_size)
        conn.commit()
    except (Exception, psycopg2.DatabaseError) as error:
        print("Error: %s" % error)
        conn.rollback()
        cursor.close()
        return 1
    print(f"Batch executed succesfully, all dataframe values inserted into the {table} table at {cursor.connection}")
    cursor.close()
    
execute_batch(conn, prueba, 'yellowtaxis')

# %%
conn.rollback()

# %%
conn.close()

# %%
def execute_many(conn, tup, cols):
    """
    Using cursor.executemany() to insert the dataframe
    """
    # Create a list of tupples from the dataframe values
    #tuples = [tuple(x) for x in df.to_numpy()]
    # Comma-separated dataframe columns
    #cols = ','.join(list(df.columns))
    # SQL quert to execute
    query  = "INSERT INTO pruebados(%s) VALUES(%%s,%%s,%%s)" % (cols)
    cursor = conn.cursor()
    try:
        cursor.executemany(query, tuples)
        conn.commit()
    except (Exception, psycopg2.DatabaseError) as error:
        print("Error: %s" % error)
        conn.rollback()
        cursor.close()
        return 1
    print("execute_many() done")
    cursor.close()

# %%
execute_many(conn, tuples, cols)

# %%
prueba.head()

# %%
engine = create_engine('postgresql+psycopg2://postgres:Snowdav3@127.0.0.1/taxis')
engine
conection = engine.connect()

# %%
spark = SparkSession.builder. \
            appName('big_data_tools'). \
            config('spark.sql.repl.eagerEval.enabled', True). \
            config('spark.sql.session.timeZone', 'UTC'). \
            config('spark.driver.memory', '16G'). \
            config('spark.driver.maxResultSize', '2G'). \
            config("spark.jars", "/home/david/Downloads/postgresql-42.2.19.jar"). \
            getOrCreate()

# master('local[*]'). \

df = spark.read \
    .format("jdbc") \
    .option("url", "jdbc:postgresql://127.0.0.1/taxis") \
    .option("dbtable", "yellowtaxis") \
    .option("user", "postgres") \
    .option("password", "Snowdav3") \
    .option("driver", "org.postgresql.Driver") \
    .load()

df.printSchema()

# %%
import pandas as pd
df = pd.read_csv("2020_yellow_jan_feb_mar.csv")
# Out:
# /Users/davidblanco/opt/miniconda3/envs/django_env/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3251: DtypeWarning: Columns (9) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
import sqlite3
conn = sqlite3.connect("../taxis.db")
df.to_sql('yellowtaxis', conn, if_exists='replace', index=False)
